# %%
from qiskit_ibm_runtime import QiskitRuntimeService
import numpy as np
import matplotlib.pyplot as plt
from qiskit_device_benchmarking.bench_code.mrb import  MirrorRB
from qiskit import transpile
from qiskit.circuit.library import iqp
from qiskit.transpiler import generate_preset_pass_manager
from qiskit.transpiler.passes import Optimize1qGates
import os, random

# Fix random seed for numpy
SEED = 123 # pick your favorite int
os.environ["PYTHONHASHSEED"] = str(SEED)  # optional, for hash-based determinism
random.seed(SEED)
np.random.seed(SEED)

QiskitRuntimeService.save_account(
    token="QPIl2rvgomW_N1LcftivJzDadXNeM9Q4UhtyRxucMbTV", # Your token is confidential.
    # Do not share your key in public code.
    instance="crn:v1:bluemix:public:quantum-computing:us-east:a/22dc8fdbcf474c5c8b2faee4cf250adb:6907401c-f66b-4337-8c3f-807e8f1947c4::", # Optionally specify the instance to use.
    name="maria", # Optionally name this set of account credentials.
    set_as_default=True, # Optionally set these as your default credentials.
    overwrite=True   
)

service = QiskitRuntimeService()
backend = service.backend("ibm_fez")

# %%
# Define parameters for the simulated backend
num_qubits = 50
shots = 10000
lengths = [2]+[4,10,20,50,100]
num_samples = 20

# Set up the experiment object
exp = MirrorRB(
    range(num_qubits),
    lengths=lengths,
    backend=backend,
    two_qubit_gate_density=0.25,
    num_samples=num_samples, 
    seed=SEED
)

# Set run options
exp.set_run_options(shots=shots)
exp.set_transpile_options(
    basis_gates=None,      # Allows auto-translation to ECR (native for FEZ)  # Includes translation + basic routing
    seed_transpiler=SEED,    # Reproducible
)

# Run the experiment with timing
rb_data = exp.run()
print("Job IDs:", rb_data.job_ids)
# Out:
# Job IDs: ['d4efc9ulo8as739njvv0']
# DEBUG Ei: 0.43+/-0.05

# %%
from qiskit_device_benchmarking.bench_code.mrb.mirror_rb_analysis import MirrorRBAnalysis

analysis_obj = MirrorRBAnalysis()
analysis_obj.set_options(analyzed_quantity='Effective Polarization')
analysis = analysis_obj.run(rb_data)
analysis.block_for_results()
analysis.figure(0)
# Out:
# DEBUG Ei: 0.43+/-0.05

# %%
# Save the MRB plot (extract matplotlib figure from FigureData)
fig = analysis.figure(0).figure
fig.savefig(f'{job_id}/{job_id}_mrb_plot.png', dpi=300, bbox_inches='tight')

# %%
import os
import json
import qiskit
import qiskit.qasm2

# Get the job id
job_id = rb_data.job_ids[0]

# Create a folder with the job id as name
os.makedirs(job_id, exist_ok=True)

# Save qubit number
with open(f'{job_id}/{job_id}_qubits.json', 'w') as f:
    json.dump({"num_qubits": num_qubits}, f)

# Save circuits
for i, circ in enumerate(exp.circuits()):
    with open(os.path.join(job_id, f'circuit_{i}.json'), 'w') as f:
        qiskit.qasm2.dump(circ, f)

# Save the seed
with open(f'{job_id}/{job_id}_seed.json', 'w') as f:
    json.dump({"seed": SEED}, f)

# %%
exp.analysis.set_options(analyzed_quantity='Effective Polarization')
analysis = exp.analysis.run(rb_data)
# Out:
# DEBUG Ei: 0.43+/-0.05

# %%
# Get original (untranspiled) and transpiled circuits
original_circuits   = exp.circuits()              # before transpilation
transpiled_circuits = exp._transpiled_circuits()  # after transpilation

def count_1q_2q(circuits):
    total_1q = 0
    total_2q = 0
    for circ in circuits:
        for gate, count in circ.count_ops().items():
            # Adjust this list if your backend uses cx, ecz, iswap, etc. instead of cz
            if gate in {'cz', 'cx', 'ecr', 'iswap'}:  
                total_2q += count
            else:
                total_1q += count   # everything else is treated as 1-qubit gate
    return total_1q, total_2q

# Before transpilation
pre_1q, pre_2q = count_1q_2q(original_circuits)

# After transpilation
post_1q, post_2q = count_1q_2q(transpiled_circuits)

# Pretty print the summary
print("\n=== Gate Count Summary (all RB circuits) ===")
print(f"Before transpilation :  1Q gates = {pre_1q:6d}   |   2Q gates = {pre_2q:5d}")
print(f"After  transpilation :  1Q gates = {post_1q:6d}   |   2Q gates = {post_2q:5d}")
print(f"Overhead             :  1Q +{post_1q - pre_1q:+6d}   |   2Q +{post_2q - pre_2q:+5d}")
print("==========================================\n")
# Out:
# === Gate Count Summary (all RB circuits) ===
# Before transpilation :  1Q gates = 310068   |   2Q gates = 46926
# After  transpilation :  1Q gates = 704584   |   2Q gates = 46926
# Overhead             :  1Q ++394516   |   2Q +   +0
# ==========================================

# %%
# Count operations after transpilation
print("\nOperations after transpilation for circuit 0:")
transpiled_circuits= exp._transpiled_circuits()
print(transpiled_circuits[0].count_ops())
print("\n1Q and 2Q gates after transpilation for all circuits:")
for i, circ in enumerate(transpiled_circuits):
    total_1q_gates_trans = 0
    total_2q_gates_trans = 0
    for gate, count in circ.count_ops().items():
        if gate in ['cz']:
            total_2q_gates_trans += count
        else:
            total_1q_gates_trans += count
    print(f"Circuit {i} transpiled: Total 1Q gates: {total_1q_gates_trans}, Total 2Q gates: {total_2q_gates_trans}")
# Out:
# Operations after transpilation for circuit 0:
# OrderedDict({'rz': 363, 'sx': 144, 'x': 87, 'measure': 50, 'cz': 24, 'barrier': 8})
#
# 1Q and 2Q gates after transpilation for all circuits:
# Circuit 0 transpiled: Total 1Q gates: 652, Total 2Q gates: 24
# Circuit 1 transpiled: Total 1Q gates: 1018, Total 2Q gates: 52
# Circuit 2 transpiled: Total 1Q gates: 2075, Total 2Q gates: 124
# Circuit 3 transpiled: Total 1Q gates: 3883, Total 2Q gates: 242
# Circuit 4 transpiled: Total 1Q gates: 9320, Total 2Q gates: 640
# Circuit 5 transpiled: Total 1Q gates: 18331, Total 2Q gates: 1302
# Circuit 6 transpiled: Total 1Q gates: 672, Total 2Q gates: 26
# Circuit 7 transpiled: Total 1Q gates: 1046, Total 2Q gates: 48
# Circuit 8 transpiled: Total 1Q gates: 2135, Total 2Q gates: 124
# Circuit 9 transpiled: Total 1Q gates: 3934, Total 2Q gates: 260
# Circuit 10 transpiled: Total 1Q gates: 9275, Total 2Q gates: 634
# Circuit 11 transpiled: Total 1Q gates: 18181, Total 2Q gates: 1218
# Circuit 12 transpiled: Total 1Q gates: 648, Total 2Q gates: 18
# Circuit 13 transpiled: Total 1Q gates: 1016, Total 2Q gates: 44
# Circuit 14 transpiled: Total 1Q gates: 2126, Total 2Q gates: 128
# Circuit 15 transpiled: Total 1Q gates: 3911, Total 2Q gates: 264
# Circuit 16 transpiled: Total 1Q gates: 9303, Total 2Q gates: 640
# Circuit 17 transpiled: Total 1Q gates: 18333, Total 2Q gates: 1296
# Circuit 18 transpiled: Total 1Q gates: 674, Total 2Q gates: 22
# Circuit 19 transpiled: Total 1Q gates: 1046, Total 2Q gates: 54
# Circuit 20 transpiled: Total 1Q gates: 2177, Total 2Q gates: 142
# Circuit 21 transpiled: Total 1Q gates: 3993, Total 2Q gates: 282
# Circuit 22 transpiled: Total 1Q gates: 9335, Total 2Q gates: 640
# Circuit 23 transpiled: Total 1Q gates: 18205, Total 2Q gates: 1266
# Circuit 24 transpiled: Total 1Q gates: 698, Total 2Q gates: 26
# Circuit 25 transpiled: Total 1Q gates: 1045, Total 2Q gates: 48
# Circuit 26 transpiled: Total 1Q gates: 2110, Total 2Q gates: 122
# Circuit 27 transpiled: Total 1Q gates: 3909, Total 2Q gates: 252
# Circuit 28 transpiled: Total 1Q gates: 9254, Total 2Q gates: 610
# Circuit 29 transpiled: Total 1Q gates: 18147, Total 2Q gates: 1242
# Circuit 30 transpiled: Total 1Q gates: 670, Total 2Q gates: 28
# Circuit 31 transpiled: Total 1Q gates: 1027, Total 2Q gates: 56
# Circuit 32 transpiled: Total 1Q gates: 2100, Total 2Q gates: 132
# Circuit 33 transpiled: Total 1Q gates: 3876, Total 2Q gates: 252
# Circuit 34 transpiled: Total 1Q gates: 9307, Total 2Q gates: 646
# Circuit 35 transpiled: Total 1Q gates: 18304, Total 2Q gates: 1286
# Circuit 36 transpiled: Total 1Q gates: 677, Total 2Q gates: 28
# Circuit 37 transpiled: Total 1Q gates: 1046, Total 2Q gates: 56
# Circuit 38 transpiled: Total 1Q gates: 2122, Total 2Q gates: 136
# Circuit 39 transpiled: Total 1Q gates: 3933, Total 2Q gates: 256
# Circuit 40 transpiled: Total 1Q gates: 9398, Total 2Q gates: 644
# Circuit 41 transpiled: Total 1Q gates: 18358, Total 2Q gates: 1280
# Circuit 42 transpiled: Total 1Q gates: 658, Total 2Q gates: 20
# Circuit 43 transpiled: Total 1Q gates: 1009, Total 2Q gates: 40
# Circuit 44 transpiled: Total 1Q gates: 2098, Total 2Q gates: 116
# Circuit 45 transpiled: Total 1Q gates: 3922, Total 2Q gates: 244
# Circuit 46 transpiled: Total 1Q gates: 9352, Total 2Q gates: 636
# Circuit 47 transpiled: Total 1Q gates: 18283, Total 2Q gates: 1238
# Circuit 48 transpiled: Total 1Q gates: 657, Total 2Q gates: 32
# Circuit 49 transpiled: Total 1Q gates: 1028, Total 2Q gates: 58
# Circuit 50 transpiled: Total 1Q gates: 2112, Total 2Q gates: 146
# Circuit 51 transpiled: Total 1Q gates: 3891, Total 2Q gates: 272
# Circuit 52 transpiled: Total 1Q gates: 9295, Total 2Q gates: 670
# Circuit 53 transpiled: Total 1Q gates: 18266, Total 2Q gates: 1298
# Circuit 54 transpiled: Total 1Q gates: 698, Total 2Q gates: 30
# Circuit 55 transpiled: Total 1Q gates: 1056, Total 2Q gates: 56
# Circuit 56 transpiled: Total 1Q gates: 2135, Total 2Q gates: 132
# Circuit 57 transpiled: Total 1Q gates: 3925, Total 2Q gates: 260
# Circuit 58 transpiled: Total 1Q gates: 9272, Total 2Q gates: 648
# Circuit 59 transpiled: Total 1Q gates: 18237, Total 2Q gates: 1284
# Circuit 60 transpiled: Total 1Q gates: 667, Total 2Q gates: 26
# Circuit 61 transpiled: Total 1Q gates: 1039, Total 2Q gates: 54
# Circuit 62 transpiled: Total 1Q gates: 2099, Total 2Q gates: 122
# Circuit 63 transpiled: Total 1Q gates: 3881, Total 2Q gates: 240
# Circuit 64 transpiled: Total 1Q gates: 9205, Total 2Q gates: 620
# Circuit 65 transpiled: Total 1Q gates: 18094, Total 2Q gates: 1244
# Circuit 66 transpiled: Total 1Q gates: 668, Total 2Q gates: 26
# Circuit 67 transpiled: Total 1Q gates: 1018, Total 2Q gates: 46
# Circuit 68 transpiled: Total 1Q gates: 2105, Total 2Q gates: 118
# Circuit 69 transpiled: Total 1Q gates: 3880, Total 2Q gates: 250
# Circuit 70 transpiled: Total 1Q gates: 9303, Total 2Q gates: 590
# Circuit 71 transpiled: Total 1Q gates: 18340, Total 2Q gates: 1240
# Circuit 72 transpiled: Total 1Q gates: 692, Total 2Q gates: 32
# Circuit 73 transpiled: Total 1Q gates: 1067, Total 2Q gates: 56
# Circuit 74 transpiled: Total 1Q gates: 2158, Total 2Q gates: 140
# Circuit 75 transpiled: Total 1Q gates: 3892, Total 2Q gates: 260
# Circuit 76 transpiled: Total 1Q gates: 9187, Total 2Q gates: 626
# Circuit 77 transpiled: Total 1Q gates: 18175, Total 2Q gates: 1228
# Circuit 78 transpiled: Total 1Q gates: 660, Total 2Q gates: 28
# Circuit 79 transpiled: Total 1Q gates: 1013, Total 2Q gates: 48
# Circuit 80 transpiled: Total 1Q gates: 2064, Total 2Q gates: 110
# Circuit 81 transpiled: Total 1Q gates: 3812, Total 2Q gates: 214
# Circuit 82 transpiled: Total 1Q gates: 9229, Total 2Q gates: 592
# Circuit 83 transpiled: Total 1Q gates: 18192, Total 2Q gates: 1180
# Circuit 84 transpiled: Total 1Q gates: 667, Total 2Q gates: 22
# Circuit 85 transpiled: Total 1Q gates: 1036, Total 2Q gates: 50
# Circuit 86 transpiled: Total 1Q gates: 2101, Total 2Q gates: 124
# Circuit 87 transpiled: Total 1Q gates: 3924, Total 2Q gates: 256
# Circuit 88 transpiled: Total 1Q gates: 9309, Total 2Q gates: 614
# Circuit 89 transpiled: Total 1Q gates: 18301, Total 2Q gates: 1238
# Circuit 90 transpiled: Total 1Q gates: 625, Total 2Q gates: 20
# Circuit 91 transpiled: Total 1Q gates: 992, Total 2Q gates: 52
# Circuit 92 transpiled: Total 1Q gates: 2047, Total 2Q gates: 126
# Circuit 93 transpiled: Total 1Q gates: 3833, Total 2Q gates: 254
# Circuit 94 transpiled: Total 1Q gates: 9227, Total 2Q gates: 630
# Circuit 95 transpiled: Total 1Q gates: 18105, Total 2Q gates: 1266
# Circuit 96 transpiled: Total 1Q gates: 662, Total 2Q gates: 20
# Circuit 97 transpiled: Total 1Q gates: 1047, Total 2Q gates: 48
# Circuit 98 transpiled: Total 1Q gates: 2123, Total 2Q gates: 130
# Circuit 99 transpiled: Total 1Q gates: 3911, Total 2Q gates: 260
# Circuit 100 transpiled: Total 1Q gates: 9349, Total 2Q gates: 660
# Circuit 101 transpiled: Total 1Q gates: 18315, Total 2Q gates: 1268
# Circuit 102 transpiled: Total 1Q gates: 691, Total 2Q gates: 26
# Circuit 103 transpiled: Total 1Q gates: 1046, Total 2Q gates: 52
# Circuit 104 transpiled: Total 1Q gates: 2103, Total 2Q gates: 120
# Circuit 105 transpiled: Total 1Q gates: 3877, Total 2Q gates: 244
# Circuit 106 transpiled: Total 1Q gates: 9314, Total 2Q gates: 638
# Circuit 107 transpiled: Total 1Q gates: 18255, Total 2Q gates: 1250
# Circuit 108 transpiled: Total 1Q gates: 652, Total 2Q gates: 20
# Circuit 109 transpiled: Total 1Q gates: 1007, Total 2Q gates: 46
# Circuit 110 transpiled: Total 1Q gates: 2082, Total 2Q gates: 122
# Circuit 111 transpiled: Total 1Q gates: 3864, Total 2Q gates: 252
# Circuit 112 transpiled: Total 1Q gates: 9256, Total 2Q gates: 638
# Circuit 113 transpiled: Total 1Q gates: 18211, Total 2Q gates: 1268
# Circuit 114 transpiled: Total 1Q gates: 647, Total 2Q gates: 22
# Circuit 115 transpiled: Total 1Q gates: 1002, Total 2Q gates: 50
# Circuit 116 transpiled: Total 1Q gates: 2044, Total 2Q gates: 120
# Circuit 117 transpiled: Total 1Q gates: 3866, Total 2Q gates: 262
# Circuit 118 transpiled: Total 1Q gates: 9277, Total 2Q gates: 636
# Circuit 119 transpiled: Total 1Q gates: 18212, Total 2Q gates: 1262

# %%
# Count operations before transpilation for circuit 0
print("Operations before transpilation:")
original_circuits = exp.circuits()
print(original_circuits[0].count_ops())
# Count 1Q and 2Q for each circuit before transpilation
print("1Q and 2Q gates before transpilation for all circuits:")
for i, circ in enumerate(original_circuits):
    total_1Q_gates = 0
    total_2Q_gates = 0
    for gate, count in circ.count_ops().items():
        if gate in ['cz']:
            total_2Q_gates += count
        else:
            total_1Q_gates += count
    print(f"Circuit {i}: Total 1Q gates: {total_1Q_gates}, Total 2Q gates: {total_2Q_gates}")
# Out:
# Operations before transpilation:
# OrderedDict({'Clifford-1Q(0)': 51, 'measure': 50, 'Clifford-1Q(18)': 48, 'Clifford-1Q(6)': 43, 'Clifford-1Q(12)': 40, 'cx': 24, 'Clifford-1Q(20)': 12, 'Clifford-1Q(5)': 11, 'Clifford-1Q(3)': 11, 'Clifford-1Q(4)': 10, 'Clifford-1Q(19)': 10, 'Clifford-1Q(22)': 10, 'Clifford-1Q(7)': 10, 'Clifford-1Q(15)': 8, 'Clifford-1Q(11)': 8, 'Clifford-1Q(13)': 8, 'barrier': 8, 'Clifford-1Q(1)': 6, 'Clifford-1Q(21)': 5, 'Clifford-1Q(17)': 5, 'Clifford-1Q(16)': 2, 'Clifford-1Q(10)': 2, 'Clifford-1Q(9)': 1, 'Clifford-1Q(23)': 1})
# 1Q and 2Q gates before transpilation for all circuits:
# Circuit 0: Total 1Q gates: 384, Total 2Q gates: 0
# Circuit 1: Total 1Q gates: 560, Total 2Q gates: 0
# Circuit 2: Total 1Q gates: 1100, Total 2Q gates: 0
# Circuit 3: Total 1Q gates: 2002, Total 2Q gates: 0
# Circuit 4: Total 1Q gates: 4664, Total 2Q gates: 0
# Circuit 5: Total 1Q gates: 9102, Total 2Q gates: 0
# Circuit 6: Total 1Q gates: 382, Total 2Q gates: 0
# Circuit 7: Total 1Q gates: 564, Total 2Q gates: 0
# Circuit 8: Total 1Q gates: 1100, Total 2Q gates: 0
# Circuit 9: Total 1Q gates: 1984, Total 2Q gates: 0
# Circuit 10: Total 1Q gates: 4670, Total 2Q gates: 0
# Circuit 11: Total 1Q gates: 9186, Total 2Q gates: 0
# Circuit 12: Total 1Q gates: 390, Total 2Q gates: 0
# Circuit 13: Total 1Q gates: 568, Total 2Q gates: 0
# Circuit 14: Total 1Q gates: 1096, Total 2Q gates: 0
# Circuit 15: Total 1Q gates: 1980, Total 2Q gates: 0
# Circuit 16: Total 1Q gates: 4664, Total 2Q gates: 0
# Circuit 17: Total 1Q gates: 9108, Total 2Q gates: 0
# Circuit 18: Total 1Q gates: 386, Total 2Q gates: 0
# Circuit 19: Total 1Q gates: 558, Total 2Q gates: 0
# Circuit 20: Total 1Q gates: 1082, Total 2Q gates: 0
# Circuit 21: Total 1Q gates: 1962, Total 2Q gates: 0
# Circuit 22: Total 1Q gates: 4664, Total 2Q gates: 0
# Circuit 23: Total 1Q gates: 9138, Total 2Q gates: 0
# Circuit 24: Total 1Q gates: 382, Total 2Q gates: 0
# Circuit 25: Total 1Q gates: 564, Total 2Q gates: 0
# Circuit 26: Total 1Q gates: 1102, Total 2Q gates: 0
# Circuit 27: Total 1Q gates: 1992, Total 2Q gates: 0
# Circuit 28: Total 1Q gates: 4694, Total 2Q gates: 0
# Circuit 29: Total 1Q gates: 9162, Total 2Q gates: 0
# Circuit 30: Total 1Q gates: 380, Total 2Q gates: 0
# Circuit 31: Total 1Q gates: 556, Total 2Q gates: 0
# Circuit 32: Total 1Q gates: 1092, Total 2Q gates: 0
# Circuit 33: Total 1Q gates: 1992, Total 2Q gates: 0
# Circuit 34: Total 1Q gates: 4658, Total 2Q gates: 0
# Circuit 35: Total 1Q gates: 9118, Total 2Q gates: 0
# Circuit 36: Total 1Q gates: 380, Total 2Q gates: 0
# Circuit 37: Total 1Q gates: 556, Total 2Q gates: 0
# Circuit 38: Total 1Q gates: 1088, Total 2Q gates: 0
# Circuit 39: Total 1Q gates: 1988, Total 2Q gates: 0
# Circuit 40: Total 1Q gates: 4660, Total 2Q gates: 0
# Circuit 41: Total 1Q gates: 9124, Total 2Q gates: 0
# Circuit 42: Total 1Q gates: 388, Total 2Q gates: 0
# Circuit 43: Total 1Q gates: 572, Total 2Q gates: 0
# Circuit 44: Total 1Q gates: 1108, Total 2Q gates: 0
# Circuit 45: Total 1Q gates: 2000, Total 2Q gates: 0
# Circuit 46: Total 1Q gates: 4668, Total 2Q gates: 0
# Circuit 47: Total 1Q gates: 9166, Total 2Q gates: 0
# Circuit 48: Total 1Q gates: 376, Total 2Q gates: 0
# Circuit 49: Total 1Q gates: 554, Total 2Q gates: 0
# Circuit 50: Total 1Q gates: 1078, Total 2Q gates: 0
# Circuit 51: Total 1Q gates: 1972, Total 2Q gates: 0
# Circuit 52: Total 1Q gates: 4634, Total 2Q gates: 0
# Circuit 53: Total 1Q gates: 9106, Total 2Q gates: 0
# Circuit 54: Total 1Q gates: 378, Total 2Q gates: 0
# Circuit 55: Total 1Q gates: 556, Total 2Q gates: 0
# Circuit 56: Total 1Q gates: 1092, Total 2Q gates: 0
# Circuit 57: Total 1Q gates: 1984, Total 2Q gates: 0
# Circuit 58: Total 1Q gates: 4656, Total 2Q gates: 0
# Circuit 59: Total 1Q gates: 9120, Total 2Q gates: 0
# Circuit 60: Total 1Q gates: 382, Total 2Q gates: 0
# Circuit 61: Total 1Q gates: 558, Total 2Q gates: 0
# Circuit 62: Total 1Q gates: 1102, Total 2Q gates: 0
# Circuit 63: Total 1Q gates: 2004, Total 2Q gates: 0
# Circuit 64: Total 1Q gates: 4684, Total 2Q gates: 0
# Circuit 65: Total 1Q gates: 9160, Total 2Q gates: 0
# Circuit 66: Total 1Q gates: 382, Total 2Q gates: 0
# Circuit 67: Total 1Q gates: 566, Total 2Q gates: 0
# Circuit 68: Total 1Q gates: 1106, Total 2Q gates: 0
# Circuit 69: Total 1Q gates: 1994, Total 2Q gates: 0
# Circuit 70: Total 1Q gates: 4714, Total 2Q gates: 0
# Circuit 71: Total 1Q gates: 9164, Total 2Q gates: 0
# Circuit 72: Total 1Q gates: 376, Total 2Q gates: 0
# Circuit 73: Total 1Q gates: 556, Total 2Q gates: 0
# Circuit 74: Total 1Q gates: 1084, Total 2Q gates: 0
# Circuit 75: Total 1Q gates: 1984, Total 2Q gates: 0
# Circuit 76: Total 1Q gates: 4678, Total 2Q gates: 0
# Circuit 77: Total 1Q gates: 9176, Total 2Q gates: 0
# Circuit 78: Total 1Q gates: 380, Total 2Q gates: 0
# Circuit 79: Total 1Q gates: 564, Total 2Q gates: 0
# Circuit 80: Total 1Q gates: 1114, Total 2Q gates: 0
# Circuit 81: Total 1Q gates: 2030, Total 2Q gates: 0
# Circuit 82: Total 1Q gates: 4712, Total 2Q gates: 0
# Circuit 83: Total 1Q gates: 9224, Total 2Q gates: 0
# Circuit 84: Total 1Q gates: 386, Total 2Q gates: 0
# Circuit 85: Total 1Q gates: 562, Total 2Q gates: 0
# Circuit 86: Total 1Q gates: 1100, Total 2Q gates: 0
# Circuit 87: Total 1Q gates: 1988, Total 2Q gates: 0
# Circuit 88: Total 1Q gates: 4690, Total 2Q gates: 0
# Circuit 89: Total 1Q gates: 9166, Total 2Q gates: 0
# Circuit 90: Total 1Q gates: 388, Total 2Q gates: 0
# Circuit 91: Total 1Q gates: 560, Total 2Q gates: 0
# Circuit 92: Total 1Q gates: 1098, Total 2Q gates: 0
# Circuit 93: Total 1Q gates: 1990, Total 2Q gates: 0
# Circuit 94: Total 1Q gates: 4674, Total 2Q gates: 0
# Circuit 95: Total 1Q gates: 9138, Total 2Q gates: 0
# Circuit 96: Total 1Q gates: 388, Total 2Q gates: 0
# Circuit 97: Total 1Q gates: 564, Total 2Q gates: 0
# Circuit 98: Total 1Q gates: 1094, Total 2Q gates: 0
# Circuit 99: Total 1Q gates: 1984, Total 2Q gates: 0
# Circuit 100: Total 1Q gates: 4644, Total 2Q gates: 0
# Circuit 101: Total 1Q gates: 9136, Total 2Q gates: 0
# Circuit 102: Total 1Q gates: 382, Total 2Q gates: 0
# Circuit 103: Total 1Q gates: 560, Total 2Q gates: 0
# Circuit 104: Total 1Q gates: 1104, Total 2Q gates: 0
# Circuit 105: Total 1Q gates: 2000, Total 2Q gates: 0
# Circuit 106: Total 1Q gates: 4666, Total 2Q gates: 0
# Circuit 107: Total 1Q gates: 9154, Total 2Q gates: 0
# Circuit 108: Total 1Q gates: 388, Total 2Q gates: 0
# Circuit 109: Total 1Q gates: 566, Total 2Q gates: 0
# Circuit 110: Total 1Q gates: 1102, Total 2Q gates: 0
# Circuit 111: Total 1Q gates: 1992, Total 2Q gates: 0
# Circuit 112: Total 1Q gates: 4666, Total 2Q gates: 0
# Circuit 113: Total 1Q gates: 9136, Total 2Q gates: 0
# Circuit 114: Total 1Q gates: 386, Total 2Q gates: 0
# Circuit 115: Total 1Q gates: 562, Total 2Q gates: 0
# Circuit 116: Total 1Q gates: 1104, Total 2Q gates: 0
# Circuit 117: Total 1Q gates: 1982, Total 2Q gates: 0
# Circuit 118: Total 1Q gates: 4668, Total 2Q gates: 0
# Circuit 119: Total 1Q gates: 9142, Total 2Q gates: 0
